# %% [markdown]
# # Title
# ## Subtitle
# ### Smaller Subtitle
# **bold**
# *italic*
# [link]pa dodamo link
# This is how to print text in Terminal using Pytho

# %%
print("Hello World")
# Out:
# Hello World

# %%
10 * 5
(8 + 2) / 2
"Python" + " " + "Notebook"
# Out:
# 'Python Notebook'

# %%
10 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 10 / 0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # My First Jupyter Notebook
# This is an **important analysis** I'm doing for the library.
# ## What I'm doing:
# - Importing data
# - Analyzing the number of rentals
# - Displaying charts
# ### Link to documentation:
# [Official Jupyterm Guide](https://jupyter-notebook.readthedocs.io/en/stable/)

# %% [raw]
# This cell will not execute code or display formatted text.
# It will be saved exactly as written.
