# %% [markdown]
# # Aritmetic operation simple Python demonstration
# *Author*: Vuk

# %% [markdown]
# ## Step 1: Declare variables:

# %%
num_a = 5
num_b = 10

# %% [markdown]
# ## Step 2: Calculater arithmetic operations:

# %%
sum = num_a + num_b
diff = num_a - num_b
prod = num_a * num_b
ratio = num_a / num_b

# %% [markdown]
# ## Step 3: Show the results:

# %%
print(sum)
print(diff)
print(prod)
print(ratio)
# Out:
# 15
# -5
# 50
# 0.5

# %% [markdown]
# ## Conclusion
# The sum is 15, difference is -5, the product is 50, and the quotient is 0.5.
#
# I like Jupyter beacusae i can instantly see the result right below the code!
